# %%
# write a python program that takes a string from the user and print the number of characters

char=str(input("Enter character:"))
len(char)
# Out:
# Enter character: sayali
# 6

# %%
# take a string from the user and print its first and last characters

string=str(input("Enter character:"))
print(string[0],string[-1])
# Out:
# Enter character: programming
# p g

# %%
# take a string and check if it contains only digit
list="python"
print(list.isdigit())
# Out:
# False

# %%
# take a string and a character from the user .count how many times the character appears in string

name = input("Enter string:")
char=input("Enter character:")
print(name.count(char))
# Out:
# Enter string: the coders orbit
# Enter character: o
# 2

# %%
#2. Write a python function to Convert list of strings to their lengths
def str_len(lst):
     return[len(i)for i in lst]
a=["helo python"]
str_len(a)
# Out:
# [11]

# %%
#take sentence , a word to replace and the new word from the user .replace it in the sentence

name="hello"
new = input("Enter new word:")
print(new.replace("name","new"))
# Out:
# Enter new word: python
# python

# %%
#take a string and print it in reverse order

name = "sayali"
print(name[ : : -1])
# Out:
# ilayas

# %%
# take a comma-seprated string from user and split it into a list
name=input("Enter list of string:")
name.split()
# Out:
# Enter list of string: "java","python","data analytics"
# ['"java","python","data', 'analytics"']

# %%
#take s string input and check whether it is palindrome(same forword and backword)
name="python"
if name == name[ : :-1]:
    print("Palindrome")
else:
   print("Non palindrome")
# Out:
# Non palindrome

# %%
#take first name and last name from the user,and print a username in the format firstname.lastname(all lowercase)

firstname=input("Enter firstname:")
lastname=input("Enter lastname:")
print(firstname.lower())
print(lastname.lower())
# Out:
# Enter firstname: SAYALI
# Enter lastname: HADGE
# sayali
# hadge

# %%
#take an email address from the user and extract the domain name(text after the @)
email=input("Enter email:")
extract='@'+email
print(extract)
# Out:
# Enter email: thecodersorbit
# @thecodersorbit
