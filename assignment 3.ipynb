# %%
#factorial

num  = int(input("enter number"))
fact = 1
for i in range(1,num + 1):
 fact = num * i  
print("Fact: {fact}")
# Out:
# enter number 3
# Fact: {fact}

# %%
#write a program to print all numbers from 1 to 500 that are divisible by 7 and 11

num = int(input("enter a number(1-500)"))
for i in range(1, 500):
   if i % 7 == 0 and i % 11 == 0:
      print(i)
# Out:
# enter a number(1-500) 45
# 77
# 154
# 231
# 308
# 385
# 462

# %%
#swaps number

a = int(input("enter first number"))
b = int(input("enter second number"))
a, b == b, a
print(f"Number 1: {a}")
print(f"Number 2: {b}")
# Out:
# enter first number 6
# enter second number 7
# Number 1: 6
# Number 2: 7

# %%
#its reverse ,sum of digit and check if its divisible by 3

num = int(input("enter 3 digit number "))
reverse_num = str(num)
sum_digit = sum(int(digit) for digit in str(num))
if num % 3 == 0 :
    print("number is divisible by 3")
else:
    print("number is not divisible by 3")
# Out:
# enter 3 digit number  456
# number is divisible by 3

# %%
#vowels or consonant

char = str(input("enter character"))
if char=='a' or char=='e' or char=='i' or char=='o' or char=='u':
 print("character are vowel")
else:
    print("character are consonant")
# Out:
# enter character s
# character are consonant

# %%
p = int(input("enter principle ammount"))
r = float(input("enter rate"))
t = int(input("enter time"))
amount = p (1 + r / 100) ** t
ci = amount - p
print("compound interest: {ci}")
# Out:
# enter principle ammount 467
# enter rate 6.4
# enter time 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 r = float(input("enter rate"))
#       3 t = int(input("enter time"))
# ----> 4 amount = p (1 + r / 100) ** t
#       5 ci = amount - p
#       6 print("compound interest: {ci}")
#
# TypeError: 'int' object is not callable

# %%
#check percentage

marks = int(input("enter marks"))
total_marks = int(input("enter number"))
for i in range(5):total_marks += marks
percentage = (total_marks / 500) * 100
print("total_marks / 500")
print("percentage %")
# Out:
# enter marks 46
# enter number 345
# total_marks / 500
# percentage %

# %%
# aramstrong number square

num = int(input("enter a number"))

if num <= 999:
    h = num // 100
    u = (num % 100 //10)
    t = num % 10
    sq = (u ** 2) + (t ** 2)
    if sq == num:
        print("entered number is arnstrong number")
    else:
        print("entered number is not armstrong number")
# Out:
# enter a number 456
# entered number is not armstrong number

# %%
# aramstrong number cube

num = int(input("enter a number"))
cube = 0
if num <= 999:
    for i in str(num):
     cube += int(i) ** 3
    if cube == num:
        print("entered number is arnstrong number")
    else:
        print("entered number is not armstrong number")
# Out:
# enter a number 300
# entered number is not armstrong number
