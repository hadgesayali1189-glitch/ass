# %%
#write a python function to find the maxumum of three numbers

def find_max(a,b,c):
    return max(a,b,c)
    print("maximun of three numbers 10, 20, 30 is:", find_max 10, 20, 30)
# Out:
#   Cell In[9], line 5
#     print("maximun of three numbers 10, 20, 30 is:", find_max 10, 20, 30)
#                                                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
 #write a python function to create and print a list where the values are the square of numbers between 1 and 30

def square_list():
   return[i ** 2 for i in range(1, 31)]
    # return [i ** 2]
print("square of numbers is:", square_list())
# Out:
# square of numbers is: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900]

# %%
#write a python function to check whether a number falls within a fiven ranges

def check_range(num, b, c):
    retrun b <= num <= c:
    print("range if 20, 25, 30:", check_range(20, 25, 30))
# Out:
#   Cell In[23], line 4
#     retrun b <= num <= c:
#            ^
# SyntaxError: invalid syntax

# %%
#create a python program with user defined to calculate the area of triangle

def calculate_area(base, height):
    return 0.5 * base * height
    base = 20
    height = 10
    print("area of triangle:", calculate_area(base, height))

# %%
#write a python program that defines user defined function to calculate the volume of a cube and a sphere

def cube_volume(side):
    return side ** 3
    print("volume of cube is:", cube_volume(5))
def sphere_volume(r):
    retrun (4/3) * math.pi (r ** 3)
    print("volume of sphere is:", sphere_volume(3))

# %%
#create a python program with user defined function to calculate the volume and surface area of a cylinder

def volume_cylinder(radius, height):
    retrun pi * (radius ** 2) * height

def surface_cylinder(radius, height):
    retrun 2 * math.pi * radius * (height + radius)

radius = 5
height = 7

print("volume of cylinder:", volume_cylinder(height, radius))
print("surface area of cylinder:", surface_cylinder(radius, height))
# Out:
#   Cell In[35], line 4
#     retrun pi * (radius ** 2) * height
#            ^
# SyntaxError: invalid syntax

# %%
#write a python program thar defines a user defined function calculate_square_area(side) which takes the side lenght of square as input and retrun its area

def calculate_square_area(side):
    return side ** 2
side = 3
print("calculation of area of side is:",calculate_square_area(side))
# Out:
# calculation of area of side is: 9

# %%
def calculate_square_perimeter(side):
    return 4 * side
side = 6
print("calculation of square perimeter:",calculate_square_perimeter(side))
# Out:
# calculation of square perimeter: 24

# %%
def calculate_hypotenuse(side1, side2):
    return math.sqrt(side**2 + side**2)
side1 = 5
side2 = 8
print("hypotenuse of right angled triangle:", calculate_hypotenuse(side1, side2))
# Out:
# hypotenuse of right angled triangle: 8.48528137423857
