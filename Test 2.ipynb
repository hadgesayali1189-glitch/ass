# %%
#1 convert each integer into the number obtained by multiplying its largest digit with the reverse of its smallest digit 
l=[2,3,54,5,37]
def multi_rev(x):
# Out:
#   Cell In[4], line 5
#
#     ^
# _IncompleteInputError: incomplete input

# %%
# for each number,compute the total of digit difference taken in circular order
from functools import reduce
num=[357]
def diff_digit():
    return x-x-x
diff=list(reduce(diff_digit,num))
print(diff)

# %%
#
#num=int(input("enter number:"))
def sum_of_fact(x):
    fact = 1
    
position = 1
for i in range(1,num + 1):
 fact = num * i 
 sum +=fact 
    
print("Fact:", fact)
# Out:
# Fact: 25

# %%
#9 convert each number into the average(integer part )of all two digit combinations formed from its digit

l=[2,23,54]
def avg(x,y,z):
     return x + y + z /3
newl=list(map(lambda:x + y + z / 3,l))
#average =(lambda x: x + y + z /3)
print(newl)

# %%
l= [23,231,43,52,26,57]
digit = 0
new=[]
def digit_prod(x):
    return digit * l
new = list(map(digit_prod,l))
print(new)
# Out:
# [[], [], [], [], [], []]
