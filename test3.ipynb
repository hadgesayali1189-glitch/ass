# %%
name ="Alpha#Beta123Gamma@@Delta456"
name2=" "
print(name.isalpha())
# Out:
# False

# %%
name ="the coders orbit"
vowels = "aeiou"
ord("t")
# Out:
# 116

# %%
list1=[3,7,11,19]
list2=[2,4,6,8]
#return #list1 * list2  +list1-list2
a = lambda list1,list2: list * list2 + list1_list2
combine=list(zip(list1,list2))
a = lambda list1,list2: list * list2 + list1_list2
print(combine,a)
#print(a)
# Out:
# [(3, 2), (7, 4), (11, 6), (19, 8)] <function <lambda> at 0x000002A8CCA53560>

# %%
num=[12,5,27,9,44,63,28,7]
a=list(map(num(lambda:num % 2 == 0 or num % 3==0)))
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 2
#       1 num=[12,5,27,9,44,63,28,7]
# ----> 2 a=list(map(num(lambda:num % 2 == 0 or num % 3==0)))
#       3 print(a)
#
# TypeError: 'list' object is not callable

# %%
name = "data analytics"
print(name[ ::-1])
# Out:
# scitylana atad

# %%
num=[1,2,3,4]
str=["data analytics"]
a = list(enumrate(num ,101))
print(str.uppercase())
print(name[::-1])
# Out:
# scitylana atad

# %%
name="aaAbBBccCaaaDDdd"
name.count(name)
# Out:
# 1

# %%
name="DaTa AnALyTiCs"
name.swapcase()
# Out:
# 'dAtA aNalYtIcS'

# %%
name=['alpha','beta','gamma','delta']
num=[92,87,66,45]
combined=list(zip(name,num))
print(combined)
# Out:
# [('alpha', 92), ('beta', 87), ('gamma', 66), ('delta', 45)]

# %%
name=['python3.1','java11','c++17','go1.18','rust2021']
print(name.isalpha())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 2
#       1 name='python3.1','java11','c++17','go1.18','rust2021'
# ----> 2 print(name.isalpha())
#
# AttributeError: 'tuple' object has no attribute 'isalpha'

# %%
name="Data Analytics"
extract = 'D.'+'A.'
print(extract)
# Out:
# D.A.

# %%
name="the coder sorbit"
name.split()
# Out:
# ['the', 'coder', 'sorbit']

# %%
list="hhhhiiPPtttooonnn"
def compress(x):
   return[name.count() if x %2==2  else x % 2 != 0 ]
   compress(list)

# %%
list=["python","java","data"]
def word (x):
    x="aeiou"
    if vowels  %  2==0:
        return x
        word(list)

# %%
str="D4a2t9a5Sci8e2n7c1e"
print("Data Science")
sorted(str)
# Out:
# Data Science
# ['1',
#  '2',
#  '2',
#  '4',
#  '5',
#  '7',
#  '8',
#  '9',
#  'D',
#  'S',
#  'a',
#  'a',
#  'c',
#  'c',
#  'e',
#  'e',
#  'i',
#  'n',
#  't']
