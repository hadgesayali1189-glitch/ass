# %%
#accept a number from the user and print all factors of the number also count how many are even and how many odd

num = int(input("enter number"))
factors = 0
factors(n)
even = 0
odd = 0
print("factors")
for i in range(1, num + 1):
    fact = num * i
    if n % i == 0:
        print(i)
    elif n % 2 == 0:
        print("even")
    else:
        print("odd")
# Out:
# enter number 45
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 num = int(input("enter number"))
#       4 factors = 0
# ----> 5 factors(n)
#       6 even = 0
#       7 odd = 0
#
# NameError: name 'n' is not defined

# %%
#take three angles and print its acute, obtuse, or right angled

a = int(input("enter angle 1:"))
b = int(input("enter angle 2:"))
c = int(input("enter angle 3:"))
if a + b + c == 180:
    if a < 90  and b < 90 and c < 90 :
        print("acute angle")
    elif a == 90 and b == 90 and c == 90:
        print("right angle")
    else:
        print("obuse angle")
# Out:
# enter angle 1: 30
# enter angle 2: 50
# enter angle 3: 110

# %%
#print least common multiple(lCM)

a = int(input("enter number"))
b = int(input("enter number"))

# %%
# triangle and hypotenuse

base = float(input("enter base:"))
height = float(input("enter height"))
sq = 0
area = 0.5 + base + height
print("area")
hypotenuse = sq(base**2 + height**2)
print("hypotenuse")
# Out:
# enter base: 45
# enter height 6
# area
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 8
#       6 area = 0.5 + base + height
#       7 print("area")
# ----> 8 hypotenuse = sq(base**2 + height**2)
#       9 print("hypotenuse")
#
# TypeError: 'int' object is not callable

# %%
#chec wether it is a prime numebr,composite,neither

num = int(input("enter number"))
n = 0
if n > 1:
 for i in range(2, n):
    if n % i == 0:
        print("composite number")
    elif n % i != 0:
        print("prime number")
    else:
        print("neither")
# Out:
# enter number 46

# %%
#print given number is harshad number or not

num = int(input("enter number:"))
def harshad_number():
 if harshad_number(num):
    print("harshad number")
 else:
    print("not harshad number")
# Out:
# enter number: 5423178690

# %%
#accept total working hours of an employee and calculate their salary

hours = float(input("enter working hours"))
if hours < 40 * 200:
     print("hours * 200")
else: 
      print("8000 + (hours - 40) * 300")
# Out:
# enter working hours 45
# hours * 200
